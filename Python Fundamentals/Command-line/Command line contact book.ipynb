# %%
# Command-Line Contact Book

# 1. Store contacts as a list of dictionaries
contacts = []

# 2. FUNCTION: Add contact
def add_contact():
    print("\n--- Add New Contact ---")
    name = input("Enter name: ")
    phone = input("Enter phone: ")
    email = input("Enter email: ")

    # Create dictionary and append to list
    new_contact = {"name": name, "phone": phone, "email": email}
    contacts.append(new_contact)
    print(f"Contact '{name}' added successfully!")

# 3. FUNCTION: Search contact by name
def search_contact(name):
    for contact in contacts:
        if contact["name"].lower() == name.lower():  # case-insensitive search
            return contact
    return None

# 4. FUNCTION: Delete contact by name
def delete_contact(name):
    contact = search_contact(name)
    if contact:
        contacts.remove(contact)
        print(f"Contact '{name}' deleted successfully!")
    else:
        print("Contact not found.")

# 5. FUNCTION: Display all contacts
def display_contacts():
    if not contacts:
        print("\nNo contacts found.")
    else:
        print("\n--- Contact List ---")
        for contact in contacts:
            print(f"Name: {contact['name']}")
            print(f"Phone: {contact['phone']}")
            print(f"Email: {contact['email']}")
            print("-" * 20)

# 6. Main menu
while True:
    print("\n=== Contact Book ===")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Delete Contact")
    print("4. Display All Contacts")
    print("5. Exit")

    choice = input("Choose an option (1-5): ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        name = input("Enter contact name to search: ")
        contact = search_contact(name)
        if contact:
            print("\nContact Found:")
            print(f"Name: {contact['name']}")
            print(f"Phone: {contact['phone']}")
            print(f"Email: {contact['email']}")
        else:
            print("Contact not found.")
    elif choice == "3":
        name = input("Enter contact name to delete: ")
        delete_contact(name)
    elif choice == "4":
        display_contacts()
    elif choice == "5":
        print("Goodbye!")
        break
    else:
        print("Invalid option. Please try again.")
# Out:
# === Contact Book ===
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display All Contacts
# 5. Exit
# Choose an option (1-5):  1
# --- Add New Contact ---
# Enter name:  Sello
# Enter phone:  0712345678
# Enter email:  selloch
# Contact 'Sello' added successfully!
#
# === Contact Book ===
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display All Contacts
# 5. Exit
# Choose an option (1-5):  2
# Enter contact name to search:  sello
# Contact Found:
# Name: Sello
# Phone: 0712345678
# Email: selloch
#
# === Contact Book ===
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display All Contacts
# 5. Exit
# Choose an option (1-5):  3
# Enter contact name to delete:  Danny
# Contact not found.
#
# === Contact Book ===
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display All Contacts
# 5. Exit
# Choose an option (1-5):  4
# --- Contact List ---
# Name: Sello
# Phone: 0712345678
# Email: selloch
# --------------------
#
# ...
