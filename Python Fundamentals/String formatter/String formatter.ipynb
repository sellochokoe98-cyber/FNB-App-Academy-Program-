# %%
# string_formatter.py

# Collect user input
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
bio = input("Enter a short bio: ")

# Create username
username = (first_name[0] + last_name).lower()

# Format full name
full_name = (first_name + " " + last_name).title()

# Clean bio
clean_bio = bio.strip()

# Count characters in the cleaned bio
bio_length = len(clean_bio)

# Replace "I am" with "I'm"
updated_bio = clean_bio.replace("I am", "I'm")

# Display the results
print("\n--- User Profile ---")
print(f"Full Name: {full_name}")
print(f"Username: {username}")
print(f"Bio: {updated_bio}")
print(f"Number of Characters in Bio: {bio_length}")
# Out:
# Enter your first name:  Sello
# Enter your last name:  Chokoe
# Enter a short bio:  I am an aspiring Data Analysis
# --- User Profile ---
# Full Name: Sello Chokoe
# Username: schokoe
# Bio: I'm an aspiring Data Analysis
# Number of Characters in Bio: 30
