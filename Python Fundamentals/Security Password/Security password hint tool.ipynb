# %%
# The Secure Password Hint Tool

# 1. Ask the user to input their secret password
password = input("Enter your secret password: ")

# 2. Remoe accidental spaces at the beggining and end
password = password.strip()

# 3. Get first and last letters


first_letter = password[0]
last_letter = password[-1]

# 4. Dispaly the hint using an f-string and uppercase letters
print("Your password hint: It starts with {irst_letter.upper()} and ends with {last_letter.upper()}")
# Out:
# Enter your secret password:  246810
# Your password hint: It starts with {irst_letter.upper()} and ends with {last_letter.upper()}
